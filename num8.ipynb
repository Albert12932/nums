# %% [markdown]
# # 8 номер ЕГЭ. Комбинаторика

# %% [markdown]
# ## Аналитическое решение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Решение программой

# %% [markdown]
# ### join()

# %%
a = ['1', '2', '3', '4', '5', '6']
print(''.join(a))
# Out:
# 123456

# %% [markdown]
# ### Itertools

# %%
from itertools import product, permutations

# %%
for i in product('123', repeat=3):
    print(i)

# %%
for i in permutations('1233'):
    print(i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import product

num = 0

for x in product(sorted(set('КАЛЕЙДОСКОП'), reverse=True), repeat=6):
    stroka = ''.join(x)
    if num%2==0 and stroka[0] == 'К' and stroka.count('Й') >= 2 and stroka.count('С') == 0 and stroka.count('Е') == 0:
        print(num)
    num += 1

# 243698

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import product

cnt = 0

for i in product('012345678', repeat=5):
    x = ''.join(i)
    if x.count('5') == 1 and x[0] != '0':
        if all(x[j] != x[j+1] for j in range(4)): #0123
            cnt += 1
print(cnt)
# Out:
# 13377

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import product

num = 0

for i in product(sorted(set('ГИРЛЯНДА')), repeat=6):
    x = ''.join(i)
    num += 1
    if num % 2==0 and x[0] != 'Я' and x.count('Д') == 3:
        print(num, x)
# Out:
# 1170 ААДДДГ
# 1172 ААДДДИ
# 1174 ААДДДН
# 1176 ААДДДЯ
# 5266 АГДДДГ
# 5268 АГДДДИ
# 5270 АГДДДН
# 5272 АГДДДЯ
# 8338 АДАДДГ
# 8340 АДАДДИ
# 8342 АДАДДН
# 8344 АДАДДЯ
# 8850 АДГДДГ
# 8852 АДГДДИ
# 8854 АДГДДН
# 8856 АДГДДЯ
# 9234 АДДАДГ
# 9236 АДДАДИ
# 9238 АДДАДН
# 9240 АДДАДЯ
# 9298 АДДГДГ
# 9300 АДДГДИ
# 9302 АДДГДН
# 9304 АДДГДЯ
# 9346 АДДДАГ
# 9348 АДДДАИ
# 9350 АДДДАН
# 9352 АДДДАЯ
# 9354 АДДДГГ
# 9356 АДДДГИ
# 9358 АДДДГН
# 9360 АДДДГЯ
# 9370 АДДДИГ
# 9372 АДДДИИ
# 9374 АДДДИН
# 9376 АДДДИЯ
# 9378 АДДДЛГ
# 9380 АДДДЛИ
# 9382 АДДДЛН
# 9384 АДДДЛЯ
# 9386 АДДДНГ
# 9388 АДДДНИ
# 9390 АДДДНН
# 9392 АДДДНЯ
# 9394 АДДДРГ
# 9396 АДДДРИ
# 9398 АДДДРН
# 9400 АДДДРЯ
# 9402 АДДДЯГ
# 9404 АДДДЯИ
# 9406 АДДДЯН
# 9408 АДДДЯЯ
# 9426 АДДИДГ
# 9428 АДДИДИ
# 9430 АДДИДН
# 9432 АДДИДЯ
# 9490 АДДЛДГ
# 9492 АДДЛДИ
# 9494 АДДЛДН
# 9496 АДДЛДЯ
# 9554 АДДНДГ
# 9556 АДДНДИ
# 9558 АДДНДН
# 9560 АДДНДЯ
# 9618 АДДРДГ
# 9620 АДДРДИ
# 9622 АДДРДН
# 9624 АДДРДЯ
# 9682 АДДЯДГ
# 9684 АДДЯДИ
# 9686 АДДЯДН
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Решение через системы счисления

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
